# %% [markdown]
# # Chapter 2 - Data Preparation Basics
# ## Segment 2 - Treating missing values

# %%
import numpy as np
import pandas as pd 

from pandas import Series, DataFrame

# %% [markdown]
# ### Figuring out what data is missing

# %%
missing = np.nan
series_obj = Series([10,20,30,missing,50,60,missing,80])
series_obj
# Out:
# 0    10.0
# 1    20.0
# 2    30.0
# 3     NaN
# 4    50.0
# 5    60.0
# 6     NaN
# 7    80.0
# dtype: float64

# %%
series_obj.isnull()
# Out:
# 0    False
# 1    False
# 2    False
# 3     True
# 4    False
# 5    False
# 6     True
# 7    False
# dtype: bool

# %% [markdown]
# ### Filling in for missing values

# %%
np.random.seed(25)
DF_obj = DataFrame(np.random.rand(36).reshape(6,6))
DF_obj
# Out:
#           0         1         2         3         4         5
# 0  0.870124  0.582277  0.278839  0.185911  0.411100  0.117376
# 1  0.684969  0.437611  0.556229  0.367080  0.402366  0.113041
# 2  0.447031  0.585445  0.161985  0.520719  0.326051  0.699186
# 3  0.366395  0.836375  0.481343  0.516502  0.383048  0.997541
# 4  0.514244  0.559053  0.034450  0.719930  0.421004  0.436935
# 5  0.281701  0.900274  0.669612  0.456069  0.289804  0.525819

# %%
DF_obj.loc[3:5,0] = missing
DF_obj.loc[1:4,5] = missing
DF_obj
# Out:
#           0         1         2         3         4         5
# 0  0.870124  0.582277  0.278839  0.185911  0.411100  0.117376
# 1  0.684969  0.437611  0.556229  0.367080  0.402366       NaN
# 2  0.447031  0.585445  0.161985  0.520719  0.326051       NaN
# 3       NaN  0.836375  0.481343  0.516502  0.383048       NaN
# 4       NaN  0.559053  0.034450  0.719930  0.421004       NaN
# 5       NaN  0.900274  0.669612  0.456069  0.289804  0.525819

# %%
filled_DF = DF_obj.fillna(0)
filled_DF
# Out:
#           0         1         2         3         4         5
# 0  0.870124  0.582277  0.278839  0.185911  0.411100  0.117376
# 1  0.684969  0.437611  0.556229  0.367080  0.402366  0.000000
# 2  0.447031  0.585445  0.161985  0.520719  0.326051  0.000000
# 3  0.000000  0.836375  0.481343  0.516502  0.383048  0.000000
# 4  0.000000  0.559053  0.034450  0.719930  0.421004  0.000000
# 5  0.000000  0.900274  0.669612  0.456069  0.289804  0.525819

# %%
filled_DF = DF_obj.fillna({0: 0.1, 5: 1.25})
filled_DF
# Out:
#           0         1         2         3         4         5
# 0  0.870124  0.582277  0.278839  0.185911  0.411100  0.117376
# 1  0.684969  0.437611  0.556229  0.367080  0.402366  1.250000
# 2  0.447031  0.585445  0.161985  0.520719  0.326051  1.250000
# 3  0.100000  0.836375  0.481343  0.516502  0.383048  1.250000
# 4  0.100000  0.559053  0.034450  0.719930  0.421004  1.250000
# 5  0.100000  0.900274  0.669612  0.456069  0.289804  0.525819

# %%
filled_DF = DF_obj.fillna(method = 'ffill') #fill forward
filled_DF
# Out:
#           0         1         2         3         4         5
# 0  0.870124  0.582277  0.278839  0.185911  0.411100  0.117376
# 1  0.684969  0.437611  0.556229  0.367080  0.402366  0.117376
# 2  0.447031  0.585445  0.161985  0.520719  0.326051  0.117376
# 3  0.447031  0.836375  0.481343  0.516502  0.383048  0.117376
# 4  0.447031  0.559053  0.034450  0.719930  0.421004  0.117376
# 5  0.447031  0.900274  0.669612  0.456069  0.289804  0.525819

# %%
filled_DF = DF_obj.fillna(method = 'bfill') #fill backward
filled_DF
# Out:
#           0         1         2         3         4         5
# 0  0.870124  0.582277  0.278839  0.185911  0.411100  0.117376
# 1  0.684969  0.437611  0.556229  0.367080  0.402366  0.525819
# 2  0.447031  0.585445  0.161985  0.520719  0.326051  0.525819
# 3       NaN  0.836375  0.481343  0.516502  0.383048  0.525819
# 4       NaN  0.559053  0.034450  0.719930  0.421004  0.525819
# 5       NaN  0.900274  0.669612  0.456069  0.289804  0.525819

# %%
filled_DF = DF_obj.interpolate(method = 'linear') #interpolate with 'linear' spacing
filled_DF
# Out:
#           0         1         2         3         4         5
# 0  0.870124  0.582277  0.278839  0.185911  0.411100  0.117376
# 1  0.684969  0.437611  0.556229  0.367080  0.402366  0.199064
# 2  0.447031  0.585445  0.161985  0.520719  0.326051  0.280753
# 3  0.447031  0.836375  0.481343  0.516502  0.383048  0.362442
# 4  0.447031  0.559053  0.034450  0.719930  0.421004  0.444130
# 5  0.447031  0.900274  0.669612  0.456069  0.289804  0.525819

# %% [markdown]
# ### Counting missing values

# %%
DF_obj
# Out:
#           0         1         2         3         4         5
# 0  0.870124  0.582277  0.278839  0.185911  0.411100  0.117376
# 1  0.684969  0.437611  0.556229  0.367080  0.402366       NaN
# 2  0.447031  0.585445  0.161985  0.520719  0.326051       NaN
# 3       NaN  0.836375  0.481343  0.516502  0.383048       NaN
# 4       NaN  0.559053  0.034450  0.719930  0.421004       NaN
# 5       NaN  0.900274  0.669612  0.456069  0.289804  0.525819

# %%
DF_obj.isnull().sum() / DF_obj.shape[0]
# Out:
# 0    0.500000
# 1    0.000000
# 2    0.000000
# 3    0.000000
# 4    0.000000
# 5    0.666667
# dtype: float64

# %% [markdown]
# ### Filtering out missing values

# %%
DF_no_na = DF_obj.dropna()
DF_no_na
# Out:
#           0         1         2         3       4         5
# 0  0.870124  0.582277  0.278839  0.185911  0.4111  0.117376

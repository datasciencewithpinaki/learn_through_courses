# %% [markdown]
# # Chapter 4 - Practical Data Visualization
# ## Segment 5 - Visualizing time series

# %%
import numpy as np
from numpy.random import randn
import pandas as pd
from pandas import Series, DataFrame

import matplotlib.pyplot as plt
from pylab import rcParams

# %%
# %matplotlib inline
rcParams['figure.figsize'] = 5, 4

# %% [markdown]
# ### The simplest time series plot

# %%
address = '../Data/Superstore-Sales.csv'

df = pd.read_csv(address, index_col='Order Date', encoding = 'cp1252', parse_dates=True)
df.head()
# Out:
#             Row ID  Order ID Order Priority  Order Quantity       Sales  \
# Order Date
# 2010-10-13       1         3            Low               6    261.5400
# 2012-10-01      49       293           High              49  10123.0200
# 2012-10-01      50       293           High              27    244.5700
# 2011-07-10      80       483           High              30   4965.7595
# 2010-08-28      85       515  Not Specified              19    394.2700
#
#             Discount       Ship Mode   Profit  Unit Price  Shipping Cost  \
# Order Date
# 2010-10-13      0.04     Regular Air  -213.25       38.94          35.00
# 2012-10-01      0.07  Delivery Truck   457.81      208.16          68.02
# 2012-10-01      0.01     Regular Air    46.71        8.69           2.99
# 2011-07-10      0.08     Regular Air  1198.97      195.99           3.99
# 2010-08-28      0.08     Regular Air    30.94       21.78           5.94
#
#                  Customer Name Province   Region Customer Segment  \
# Order Date
# 2010-10-13  Muhammed MacIntyre  Nunavut  Nunavut   Small Business
# 2012-10-01        Barry French  Nunavut  Nunavut         Consumer
# 2012-10-01        Barry French  Nunavut  Nunavut         Consumer
# 2011-07-10       Clay Rozendal  Nunavut  Nunavut        Corporate
# 2010-08-28      Carlos Soltero  Nunavut  Nunavut         Consumer
#
#            Product Category            Product Sub-Category  \
# Order Date
# 2010-10-13  Office Supplies          Storage & Organization
# 2012-10-01  Office Supplies                      Appliances
# 2012-10-01  Office Supplies  Binders and Binder Accessories
# 2011-07-10       Technology    Telephones and Communication
# 2010-08-28  Office Supplies                      Appliances
#
#                                                  Product Name  \
# Order Date
# 2010-10-13   Eldon Base for stackable storage shelf, platinum
# 2012-10-01  1.7 Cubic Foot Compact "Cube" Office Refrigera...
# 2012-10-01   Cardinal Slant-D® Ring Binder, Heavy Gauge Vinyl
# 2011-07-10                                               R380
# 2010-08-28                           Holmes HEPA Air Purifier
#
#            Product Container  Product Base Margin   Ship Date
# Order Date
# 2010-10-13         Large Box                 0.80  10/20/2010
# 2012-10-01        Jumbo Drum                 0.58   10/2/2012
# 2012-10-01         Small Box                 0.39   10/3/2012
# 2011-07-10         Small Box                 0.58   7/12/2011
# 2010-08-28        Medium Box                 0.50   8/30/2010

# %%
df['Order Quantity'].plot()

# %%
df2 = df.sample(n = 100, random_state = 25, axis = 0)
df2.head()
# Out:
#             Row ID  Order ID Order Priority  Order Quantity    Sales  \
# Order Date
# 2009-05-02    5781     40998         Medium              43  1233.22
# 2011-11-30    4673     33253  Not Specified               6    24.20
# 2009-09-25    3222     23136  Not Specified              41  9312.52
# 2011-09-25    3509     24996       Critical              36  1793.24
# 2009-07-29    1171      8551       Critical              25   185.64
#
#             Discount    Ship Mode   Profit  Unit Price  Shipping Cost  \
# Order Date
# 2009-05-02      0.05  Regular Air   385.46       29.89           1.99
# 2011-11-30      0.08  Regular Air    -5.20        4.13           1.17
# 2009-09-25      0.01  Regular Air  3039.37      218.08          18.06
# 2011-09-25      0.01  Regular Air   739.36       46.89           5.10
# 2009-07-29      0.10  Regular Air   -69.87        7.45           6.28
#
#                Customer Name          Province  Region Customer Segment  \
# Order Date
# 2009-05-02        Nora Paige  British Columbia    West   Small Business
# 2011-11-30  Katherine Murray            Quebec  Quebec      Home Office
# 2009-09-25   Barry Blumstein  British Columbia    West   Small Business
# 2011-09-25          Roy Phan           Alberta    West         Consumer
# 2009-07-29      Meg O'Connel          Manitoba  Prarie        Corporate
#
#            Product Category            Product Sub-Category  \
# Order Date
# 2009-05-02       Technology            Computer Peripherals
# 2011-11-30  Office Supplies             Pens & Art Supplies
# 2009-09-25        Furniture              Chairs & Chairmats
# 2011-09-25  Office Supplies                      Appliances
# 2009-07-29  Office Supplies  Binders and Binder Accessories
#
#                                                  Product Name  \
# Order Date
# 2009-05-02    Verbatim DVD-RAM, 5.2GB, Rewritable, Type 1, DS
# 2011-11-30                                          Newell 31
# 2009-09-25       Lifetime Advantage™ Folding Chairs, 4/Carton
# 2011-09-25   Bionaire Personal Warm Mist Humidifier/Vaporizer
# 2009-07-29  Acco Four Pocket Poly Ring Binder with Label H...
#
#            Product Container  Product Base Margin  Ship Date
# Order Date
# 2009-05-02        Small Pack                 0.50   5/3/2009
# 2011-11-30          Wrap Bag                 0.57  12/2/2011
# 2009-09-25         Large Box                 0.57  9/26/2009
# 2011-09-25        Medium Box                 0.46  9/26/2011
# 2009-07-29         Small Box                 0.40   8/1/2009

# %%
plt.xlabel('Order Date')
plt.ylabel('Order Quantity')
plt.title('Super Store Sales')

df2['Order Quantity'].plot()
